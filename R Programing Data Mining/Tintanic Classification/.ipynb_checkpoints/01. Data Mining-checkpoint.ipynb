# %% [markdown]
# # 데이터 마이닝

# %% [markdown]
# #### 1. 데이터 마이닝 프로젝트의 목적을 정의하고 이해한다.
#
# #### 2. 데이터 마이닝 문제를 만든다.
#
# #### 3. 데이터를 얻고 검증하고 수정한다.
#
# #### 4. 데이터를 탐색하고 개인화한다.
#
# #### 5. 데이터 마이닝 모델을 구축한다.
#
# #### 6. 결과를 평가하고 해석한다.
#
# #### 7. 모델을 배포하고 모니터링한다.

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
img = imread("./datamining.jpg") ; plt.figure(figsize=(15,15)) ; plt.imshow(img) ; plt.axis("off") ; plt.show()

# %%
img = imread("./Datamining2.png") ; plt.figure(figsize=(15,15)) ; plt.imshow(img) ; plt.axis("off") ; plt.show()
