# %% [markdown]
# # XGBoost 텍스트 유사도 분석 모델
#
#  - 맨 먼저 사용할 모델은 앙상블 모델 중 하나인 XGBoost 모델이다.
#
#  - XGBoost란 "eXtream Gradient Boosting"의 약자로 최근 캐글 사용자에게 큰 인기를 얻고 있는 모델 중 하나이다. XGBoost는 앙상블의 한 방법인 부스팅(Boosting) 기법을 사용하는 방법이다.
#
#  - 머신러닝 혹은 통계학에서 앙상블 기법이란 여러 개의 학습 알고리즘을 사용해 더 좋은 성능을 얻는 방법을 뜻한다. 앙상블 기법에는 배깅과 부스팅이라는 방법이 있다.
#
#  - 배깅이란 여러 개의 학습 알고리즘, 모델을 통해 각각 결과를 예측하고 모든 결과를 동등하게 보고 취합해서 결과를 얻는 방식이다. 예를 들면 랜덤 포레스트의 경우 여러 개의 의사결정 트리 결과값의 평균을 통해 결과를 얻는 배깅(Bagging)방법이다.
#
#  - 배깅의 경우 여러 알고리즘, 모델의 결과를 다 동일하게 취합하는데, 이와 다르게 부스팅은 각 결과를 순차적으로 취합하는데, 단순히 하나씩 취합하는 방법이 아니라 이전 알고리즘, 모델이 학습 후 잘못 예측한 부분에 가중치를 줘서 다시 모델로 가서 학습하는 방식이다.

# %%
from IPython.display import Image
Image("Image/eee.png")

# %% [markdown]
#  - 위에 그림에서 싱글이라고 나온 부분은 앙상블 기법이 아니라 단순히 하나의 모델만으로 결과를 내는 방법이다.
#
#  - XGBoost는 부스팅 기법 중 트리 부스팅(Tree Boosting) 기법을 활용한 모델이다.
#
#  - 트리 구조를 이용하여 배깅 기법을 사용한 앙상블 모델이 랜덤 포레스트였다면 부스팅 기법을 사용한 앙상블 모델이 XGBoost 이다.
#
#  - 최종적으로 XGBoost란 트리 부스팅 방식에 경사 하강법을 통해 최적화하는 방법이다.
#
#  - 그리고, 연산량을 줄이기 위해 의사결정 트리를 구성할 때 병렬 처리를 사용해 빠른 시간에 학습이 가능하다.

# %%
# 라이브러리
import pandas as pd
import numpy as np
import os
import json
from sklearn.model_selection  import train_test_split


# 데이터 디렉터리 설정
DATA_IN_PATH = "./data_in/"
TRAIN_Q1_DATA_FILE = 'train_q1.npy'
TRAIN_Q2_DATA_FILE = 'train_q2.npy'
TRAIN_LABEL_DATA_FILE = 'train_label.npy'


# Train 데이터 가져오기
train_q1_data = np.load(open(DATA_IN_PATH + TRAIN_Q1_DATA_FILE, 'rb'))
train_q2_data = np.load(open(DATA_IN_PATH + TRAIN_Q2_DATA_FILE, 'rb'))
train_labels = np.load(open(DATA_IN_PATH + TRAIN_LABEL_DATA_FILE, 'rb'))


# stack 함수를 사용해 두 질문을 하나의 쌍으로 묶는다.
train_input = np.stack((train_q1_data, train_q2_data), axis=1)


# 현재 형태
# [[질문A],[질문B]]
print(train_input.shape)


# 데이터 분리
# 전체 데이터의 20%를 eval 데이터로 분리
train_input, eval_input, train_label, eval_label = train_test_split(train_input, train_labels, test_size=0.2, random_state=4242)


# 모델 입력 데이터 생성
# XGBoost를 사용하려면 입력값을 DMatrix 형태로 만들어야한다.
# 적용과정에서 각 데이터에 대해 sum 함수를 사용하는데, 이는 각 데이터의 두 질문을 하나의 값으로 만들어주기 위해서다.
# 그리고, 두 개의 데이터를 묶어 하나의 리스트로 만든다.
import xgboost as xgb
train_data = xgb.DMatrix(train_input.sum(axis=1), label=train_label) # 학습 데이터 읽어 오기
eval_data = xgb.DMatrix(eval_input.sum(axis=1), label=eval_label) # 평가 데이터 읽어 오기
data_list = [(train_data, 'train'), (eval_data, 'valid')]


# 하이퍼 파라미터 설정
params = {}
params['objective'] = 'binary:logistic'   # 모델의 목적함수 : 로지스틱 회귀
params['eval_metric'] = 'rmse'            # 모델의 평가함수 : RMSE


# 모델 객체 생성
# num_boost_round(데이터 반복 횟수, Epoch) = 10,000
# early_stopping_rounds(조기 머뭄) = 10
# 데이터를 총 10,000번 반복하는데, 만약 10번 동안 에러값이 별로 줄어들지 않으면 학습을 조기에 멈추게 하는 것이다.
bst = xgb.train(params, train_data, num_boost_round = 10000, evals = data_list, early_stopping_rounds=10)
# Out:
# (298526, 2, 31)
# [0]	train-rmse:0.483618	valid-rmse:0.484195
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:0.473193	valid-rmse:0.474324
# [2]	train-rmse:0.466353	valid-rmse:0.467689
# [3]	train-rmse:0.461434	valid-rmse:0.463244
# [4]	train-rmse:0.45779	valid-rmse:0.459968
# [5]	train-rmse:0.45507	valid-rmse:0.457577
# [6]	train-rmse:0.453162	valid-rmse:0.455981
# [7]	train-rmse:0.451393	valid-rmse:0.454498
# [8]	train-rmse:0.449001	valid-rmse:0.452241
# [9]	train-rmse:0.447511	valid-rmse:0.451
# [10]	train-rmse:0.446048	valid-rmse:0.449723
# [11]	train-rmse:0.445358	valid-rmse:0.449156
# [12]	train-rmse:0.444059	valid-rmse:0.448065
# [13]	train-rmse:0.44354	valid-rmse:0.447669
# [14]	train-rmse:0.44294	valid-rmse:0.447315
# [15]	train-rmse:0.44069	valid-rmse:0.445317
# [16]	train-rmse:0.439324	valid-rmse:0.444251
# [17]	train-rmse:0.438924	valid-rmse:0.443916
# [18]	train-rmse:0.438539	valid-rmse:0.443636
# [19]	train-rmse:0.437977	valid-rmse:0.443298
# [20]	train-rmse:0.437567	valid-rmse:0.442961
# [21]	train-rmse:0.436315	valid-rmse:0.441791
# [22]	train-rmse:0.436003	valid-rmse:0.441594
# [23]	train-rmse:0.435696	valid-rmse:0.441395
# [24]	train-rmse:0.435539	valid-rmse:0.441287
# [25]	train-rmse:0.434988	valid-rmse:0.440837
# [26]	train-rmse:0.43486	valid-rmse:0.440736
# [27]	train-rmse:0.434342	valid-rmse:0.440377
# [28]	train-rmse:0.434155	valid-rmse:0.440307
# [29]	train-rmse:0.433794	valid-rmse:0.43997
# [30]	train-rmse:0.433136	valid-rmse:0.439478
# [31]	train-rmse:0.432252	valid-rmse:0.438756
# [32]	train-rmse:0.432091	valid-rmse:0.438622
# [33]	train-rmse:0.431858	valid-rmse:0.438494
# [34]	train-rmse:0.431696	valid-rmse:0.438385
# [35]	train-rmse:0.4312	valid-rmse:0.437976
# [36]	train-rmse:0.430431	valid-rmse:0.43737
# [37]	train-rmse:0.429595	valid-rmse:0.436708
# [38]	train-rmse:0.429229	valid-rmse:0.436517
# [39]	train-rmse:0.42907	valid-rmse:0.436413
# [40]	train-rmse:0.428872	valid-rmse:0.436302
# [41]	train-rmse:0.428524	valid-rmse:0.436075
# [42]	train-rmse:0.428421	valid-rmse:0.43604
# [43]	train-rmse:0.427972	valid-rmse:0.435785
# [44]	train-rmse:0.427525	valid-rmse:0.435464
# [45]	train-rmse:0.427382	valid-rmse:0.435414
# [46]	train-rmse:0.427192	valid-rmse:0.435318
# [47]	train-rmse:0.426786	valid-rmse:0.435088
# [48]	train-rmse:0.426352	valid-rmse:0.434833
# [49]	train-rmse:0.426154	valid-rmse:0.434757
# [50]	train-rmse:0.425866	valid-rmse:0.434649
# [51]	train-rmse:0.425631	valid-rmse:0.434486
# [52]	train-rmse:0.425525	valid-rmse:0.434426
# [53]	train-rmse:0.425366	valid-rmse:0.434368
# [54]	train-rmse:0.425288	valid-rmse:0.434335
# [55]	train-rmse:0.425176	valid-rmse:0.434267
# [56]	train-rmse:0.425026	valid-rmse:0.434248
# [57]	train-rmse:0.424669	valid-rmse:0.434064
# [58]	train-rmse:0.424594	valid-rmse:0.434003
# [59]	train-rmse:0.424544	valid-rmse:0.433966
# [60]	train-rmse:0.424202	valid-rmse:0.433788
# [61]	train-rmse:0.423695	valid-rmse:0.43353
# [62]	train-rmse:0.423468	valid-rmse:0.433456
# [63]	train-rmse:0.423358	valid-rmse:0.433406
# [64]	train-rmse:0.423282	valid-rmse:0.433363
# [65]	train-rmse:0.423167	valid-rmse:0.433328
# [66]	train-rmse:0.423104	valid-rmse:0.433314
# [67]	train-rmse:0.423058	valid-rmse:0.433291
# [68]	train-rmse:0.422973	valid-rmse:0.43328
# [69]	train-rmse:0.422842	valid-rmse:0.43317
# [70]	train-rmse:0.422458	valid-rmse:0.433054
# [71]	train-rmse:0.421963	valid-rmse:0.432846
# [72]	train-rmse:0.42138	valid-rmse:0.432378
# [73]	train-rmse:0.421179	valid-rmse:0.432353
# [74]	train-rmse:0.421112	valid-rmse:0.432304
# [75]	train-rmse:0.420632	valid-rmse:0.431964
# [76]	train-rmse:0.420505	valid-rmse:0.431916
# [77]	train-rmse:0.420276	valid-rmse:0.43186
# [78]	train-rmse:0.420105	valid-rmse:0.431773
# [79]	train-rmse:0.419805	valid-rmse:0.431677
# [80]	train-rmse:0.419734	valid-rmse:0.431645
# [81]	train-rmse:0.419304	valid-rmse:0.431429
# [82]	train-rmse:0.41894	valid-rmse:0.431286
# [83]	train-rmse:0.418579	valid-rmse:0.431122
# [84]	train-rmse:0.418207	valid-rmse:0.43094
# [85]	train-rmse:0.41805	valid-rmse:0.430853
# [86]	train-rmse:0.418024	valid-rmse:0.430843
# [87]	train-rmse:0.417669	valid-rmse:0.430701
# [88]	train-rmse:0.417616	valid-rmse:0.430657
# [89]	train-rmse:0.417469	valid-rmse:0.430586
# [90]	train-rmse:0.417176	valid-rmse:0.430479
# [91]	train-rmse:0.416916	valid-rmse:0.430278
# [92]	train-rmse:0.416493	valid-rmse:0.430012
# [93]	train-rmse:0.416058	valid-rmse:0.429762
# [94]	train-rmse:0.415534	valid-rmse:0.429412
# [95]	train-rmse:0.41531	valid-rmse:0.429379
# [96]	train-rmse:0.415249	valid-rmse:0.429331
# [97]	train-rmse:0.415202	valid-rmse:0.42932
# [98]	train-rmse:0.415068	valid-rmse:0.429291
# [99]	train-rmse:0.41496	valid-rmse:0.429259
# [100]	train-rmse:0.414939	valid-rmse:0.429238
# [101]	train-rmse:0.414863	valid-rmse:0.42924
# [102]	train-rmse:0.414832	valid-rmse:0.429238
# [103]	train-rmse:0.414796	valid-rmse:0.429225
# [104]	train-rmse:0.414684	valid-rmse:0.429233
# [105]	train-rmse:0.414642	valid-rmse:0.429182
# [106]	train-rmse:0.414489	valid-rmse:0.429145
# [107]	train-rmse:0.414193	valid-rmse:0.428998
# [108]	train-rmse:0.413948	valid-rmse:0.428892
# [109]	train-rmse:0.413868	valid-rmse:0.428851
# [110]	train-rmse:0.413668	valid-rmse:0.428799
# [111]	train-rmse:0.413581	valid-rmse:0.428771
# [112]	train-rmse:0.413551	valid-rmse:0.428758
# [113]	train-rmse:0.413513	valid-rmse:0.428749
# [114]	train-rmse:0.413489	valid-rmse:0.428735
# [115]	train-rmse:0.413273	valid-rmse:0.428664
# [116]	train-rmse:0.412991	valid-rmse:0.428584
# [117]	train-rmse:0.412667	valid-rmse:0.428512
# [118]	train-rmse:0.412379	valid-rmse:0.42844
# [119]	train-rmse:0.412076	valid-rmse:0.428328
# [120]	train-rmse:0.411858	valid-rmse:0.428205
# [121]	train-rmse:0.411663	valid-rmse:0.428139
# [122]	train-rmse:0.41148	valid-rmse:0.42809
# [123]	train-rmse:0.41141	valid-rmse:0.428085
# [124]	train-rmse:0.411341	valid-rmse:0.428074
# [125]	train-rmse:0.41131	valid-rmse:0.42806
# [126]	train-rmse:0.410992	valid-rmse:0.427924
# [127]	train-rmse:0.410648	valid-rmse:0.427805
# [128]	train-rmse:0.410306	valid-rmse:0.427621
# [129]	train-rmse:0.410003	valid-rmse:0.427521
# [130]	train-rmse:0.409901	valid-rmse:0.42752
# [131]	train-rmse:0.409521	valid-rmse:0.427315
# [132]	train-rmse:0.40941	valid-rmse:0.427302
# [133]	train-rmse:0.409093	valid-rmse:0.427234
# [134]	train-rmse:0.409018	valid-rmse:0.427182
# [135]	train-rmse:0.40873	valid-rmse:0.427143
# [136]	train-rmse:0.408409	valid-rmse:0.427045
# [137]	train-rmse:0.408231	valid-rmse:0.427004
# [138]	train-rmse:0.408193	valid-rmse:0.427005
# [139]	train-rmse:0.408176	valid-rmse:0.426992
# [140]	train-rmse:0.408148	valid-rmse:0.426988
# [141]	train-rmse:0.408073	valid-rmse:0.426973
# [142]	train-rmse:0.407931	valid-rmse:0.426932
# [143]	train-rmse:0.407487	valid-rmse:0.426639
# [144]	train-rmse:0.407216	valid-rmse:0.426504
# [145]	train-rmse:0.407143	valid-rmse:0.426459
# [146]	train-rmse:0.4071	valid-rmse:0.426439
# [147]	train-rmse:0.406816	valid-rmse:0.426345
# [148]	train-rmse:0.406644	valid-rmse:0.426313
# [149]	train-rmse:0.406472	valid-rmse:0.426274
# [150]	train-rmse:0.406461	valid-rmse:0.42627
# [151]	train-rmse:0.406247	valid-rmse:0.426151
# [152]	train-rmse:0.405951	valid-rmse:0.426115
# [153]	train-rmse:0.405834	valid-rmse:0.426092
# [154]	train-rmse:0.405581	valid-rmse:0.426043
# [155]	train-rmse:0.40523	valid-rmse:0.425783
# [156]	train-rmse:0.405003	valid-rmse:0.425689
# [157]	train-rmse:0.404884	valid-rmse:0.425701
# [158]	train-rmse:0.404705	valid-rmse:0.425667
# [159]	train-rmse:0.404664	valid-rmse:0.425664
# [160]	train-rmse:0.404637	valid-rmse:0.425633
# [161]	train-rmse:0.404396	valid-rmse:0.425595
# [162]	train-rmse:0.404373	valid-rmse:0.425586
# [163]	train-rmse:0.40432	valid-rmse:0.425558
# [164]	train-rmse:0.404288	valid-rmse:0.425527
# [165]	train-rmse:0.404219	valid-rmse:0.425521
# [166]	train-rmse:0.404189	valid-rmse:0.425509
# [167]	train-rmse:0.404152	valid-rmse:0.425487
# [168]	train-rmse:0.404142	valid-rmse:0.425488
# [169]	train-rmse:0.403906	valid-rmse:0.425435
# [170]	train-rmse:0.403636	valid-rmse:0.425399
# [171]	train-rmse:0.403537	valid-rmse:0.425363
# [172]	train-rmse:0.403451	valid-rmse:0.425351
# [173]	train-rmse:0.403198	valid-rmse:0.425203
# [174]	train-rmse:0.403053	valid-rmse:0.42517
# [175]	train-rmse:0.402732	valid-rmse:0.425096
# [176]	train-rmse:0.402502	valid-rmse:0.425014
# [177]	train-rmse:0.40246	valid-rmse:0.425003
# [178]	train-rmse:0.402453	valid-rmse:0.425
# [179]	train-rmse:0.402396	valid-rmse:0.42499
# [180]	train-rmse:0.402192	valid-rmse:0.424956
# [181]	train-rmse:0.402073	valid-rmse:0.424935
# [182]	train-rmse:0.401897	valid-rmse:0.424862
# [183]	train-rmse:0.40185	valid-rmse:0.424845
# [184]	train-rmse:0.401829	valid-rmse:0.424832
# [185]	train-rmse:0.401769	valid-rmse:0.424821
# [186]	train-rmse:0.401515	valid-rmse:0.424791
# [187]	train-rmse:0.401184	valid-rmse:0.424689
# [188]	train-rmse:0.400875	valid-rmse:0.424589
# [189]	train-rmse:0.400644	valid-rmse:0.424507
# [190]	train-rmse:0.400584	valid-rmse:0.424483
# [191]	train-rmse:0.40048	valid-rmse:0.42444
# [192]	train-rmse:0.400416	valid-rmse:0.42441
# [193]	train-rmse:0.400349	valid-rmse:0.42438
# [194]	train-rmse:0.400329	valid-rmse:0.424369
# [195]	train-rmse:0.400096	valid-rmse:0.424336
# [196]	train-rmse:0.400004	valid-rmse:0.42431
# [197]	train-rmse:0.399962	valid-rmse:0.424304
# [198]	train-rmse:0.399677	valid-rmse:0.424187
# [199]	train-rmse:0.399359	valid-rmse:0.423982
# [200]	train-rmse:0.399339	valid-rmse:0.423973
# [201]	train-rmse:0.399301	valid-rmse:0.423962
# [202]	train-rmse:0.399	valid-rmse:0.42391
# [203]	train-rmse:0.398731	valid-rmse:0.423818
# [204]	train-rmse:0.398491	valid-rmse:0.423729
# [205]	train-rmse:0.398201	valid-rmse:0.423677
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e98a12e6c8a7> in <module>
#      54 # early_stopping_rounds(조기 머뭄) = 10
#      55 # 데이터를 총 10,000번 반복하는데, 만약 10번 동안 에러값이 별로 줄어들지 않으면 학습을 조기에 멈추게 하는 것이다.
# ---> 56 bst = xgb.train(params, train_data, num_boost_round = 10000, evals = data_list, early_stopping_rounds=10)
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
train_input.sum(axis=1)
# Out:
# array([[   8,   18,   20, ...,    0,    0,    0],
#        [  21, 6863,   36, ...,    0,    0,    0],
#        [  11,   41,  322, ...,    0,    0,    0],
#        ...,
#        [  34,  231, 5507, ...,    0,    0,    0],
#        [   4,   22,  170, ...,    0,    0,    0],
#        [   8,   18,   10, ...,    0,    0,    0]])

# %%
# Test 데이터 불러오기
TEST_Q1_DATA_FILE = 'test_q1.npy'
TEST_Q2_DATA_FILE = 'test_q2.npy'
TEST_ID_DATA_FILE = 'test_id.npy'
test_q1_data = np.load(open(DATA_IN_PATH + TEST_Q1_DATA_FILE, 'rb'))
test_q2_data = np.load(open(DATA_IN_PATH + TEST_Q2_DATA_FILE, 'rb'))
test_id_data = np.load(open(DATA_IN_PATH + TEST_ID_DATA_FILE, 'rb'))

# 모델을 통한 Test 데이터 예측
test_input = np.stack((test_q1_data, test_q2_data), axis=1) 
test_data = xgb.DMatrix(test_input.sum(axis=1))
test_predict = bst.predict(test_data)

# %%
# 예측한 결과 저장
DATA_OUT_PATH = "./data_out/"
if not os.path.exists(DATA_OUT_PATH):
    os.makedirs(DATA_OUT_PATH)
    
output = pd.DataFrame({'test_id': test_id_data, 'is_duplicate': test_predict})
output.to_csv(DATA_OUT_PATH + 'simple_xgb.csv', index=False)
