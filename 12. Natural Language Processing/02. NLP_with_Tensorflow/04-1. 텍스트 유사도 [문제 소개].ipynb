# %% [markdown]
# # 텍스트 유사도
#
#  - 텍스트 유사도 문제란 두 문장(글)이 있을 때 두 문장 간의 유사도를 측정할 수 있는 모델을 만드는 것이다.

# %% [markdown]
# # 문제 소개
#
#  - 데이터 이름 : Quora Question Pairs
#  - 데이터 용도 : 텍스트 유사도 학습을 목적으로 사용한다.
#  - 데이터 권한 : 쿼라 권한을 가지고 있으며 캐글 가입 후 데이터를 내려받으면 문제 없다.
#  - 데이터 출처 : https://www.kaggle.com/c/quora-question-pairs/data
#
#  쿼라(Quora)는 질문을 하고 다른 사용자들로부터 답변을 받을 수 있는 서비스로이다. 실제로 딥러닝을 공부할 때도 쿼라의 질문들을 참고하면서 많은 공부를 할 수 있다.
#
#  매일 수많은 질문들이 사이트에 올라오는데 이 많은 질문 중에는 분명히 중복된 것들이 포함될 것이다. 따라서 쿼라 입장에서는 중복된 질문들을 잘 찾기만 한다면 이미 잘 작성된 답변들을 사용자들이 참고할 수 있게 하고, 더 좋은 서비스를 제공할 수 있게 된다.

# %%
from IPython.display import Image
Image("Image/quora.jpeg")
